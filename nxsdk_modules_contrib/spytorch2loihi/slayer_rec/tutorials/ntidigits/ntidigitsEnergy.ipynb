# %%
#INTEL CORPORATION CONFIDENTIAL AND PROPRIETARY
#
#Copyright © 2021 Intel Corporation.
#
#This software and the related documents are Intel copyrighted
#materials, and your use of them is governed by the express
#license under which they were provided to you (License). Unless
#the License provides otherwise, you may not use, modify, copy,
#publish, distribute, disclose or transmit  this software or the
#related documents without Intel's prior written permission.
#
#This software and the related documents are provided as is, with
#no express or implied warranties, other than those that are
#expressly stated in the License.

# %% [markdown]
# # Import modules

# %%
import os
import sys

import time
import numpy as np
import nxsdk.api.n2a as nx
import nxsdk_modules.slayer.src as nxSlayer
from nxsdk.api.enums.api_enums import ProbeParameter
from nxsdk.graph.monitor.probes import PerformanceProbeCondition
from ntidigits_dataset import NTIDIGITSDataset

os.environ['SLURM'] = '1' 
os.environ['PARTITION'] = 'nahuku32'

# %% [markdown]
# # Power measurement Dynamics
# In multichip benchmarking, there is an initial phase where some time is spent replcating the network. Power measurement is low in this region as the chip is not being utilized in this region. The energy probes return the measurements every `bufferSize * binSize` ticks. When the measurement data is being sent, the execution time is quite long. This stage should be avoided in power measurement. A suitable region for power measurement is indicated in the figure below.
#
# __Power Measurement Dynamics__
# ![Power Measurement Dynamics](notebookFigs/energyProbing2.png)
#
# __Proper Power Measurement__
# ![Proper Power Measurement](notebookFigs/properlyProbed2.png)
#
# # Run parameters
# __boardName__: name of the board
#
# __streamOnce__: It should be enabled during power measurement. In this mode, all the input data is streamed at time=1 and read from memory during execution. This eliminates data communication bottleneck between host and Loihi for energy measurement.
#
# __probeEnergy__: Flag to enable energy probing.
#
# __numChips__: Number of chips to use for measurement. More chips means better power estimation.
#
# __numLmts__: Number of lakemonts to use in a chip. More lakemonts means faster data injection. It is not very critical.
#
# __bufferSize__: size of time measurement buffer to use. Use as large as the lakemont memory allows.
#
# __binSize__: number of buffers for time measurement.
#
# __tStart__: time tick to initiate power measurement.

# %%
boardName = 'ntidigitsBenchmark'
streamOnce = True
probeEnergy = True
numChips = 32
numLmts = 3
bufferSize = 1024
binSize = 64
slack = 100
tStart = bufferSize * binSize + slack

# %% [markdown]
# # Create nxSlayer Dataset instance

# %%
dataset = nxSlayer.auto.s2lDataset(dataset = NTIDIGITSDataset(train = False))
# Out:
# Neuromorphic TIDIGITS dataset is the work of Sensors Group, Institute of
# Neuromoroinformatics, Zurich. It is publicly available under Creative
# Commons Attribution-ShareAlike 4.0 International License here:
# http://sensors.ini.uzh.ch/databases.html
#
# Please cite the following paper if you make use of it.
#
# Jithendar Anumula, Daniel Neil, Tobi Delbruck and Shih-Chii Liu,
# "Feature Representations for Neuromorphic Audio Spike Streams."
# Front. Neurosci., vol. 12, p. 23, 2018.

# %% [markdown]
# # Initialize Multichip network

# %%
net = nxSlayer.benchmark.MultiChipNetwork('ntidigits.net')

# %% [markdown]
# # Compile, setup input-output, and run the network
# For larger network, the compile time may be too long and you might encounter an issue of the Jupyter notebook dying. It is recommended to save the board using a python script and used the saved board here. Just change the compile line to use the saved board
# ```
# net.compile(boardName, regenerateBoard=False)
# ```

# %%
net.create(numChips=numChips, streamOnce=streamOnce)
net.compile(boardName, regenerateBoard=True)
net.setupIO(dataset, numLmts=numLmts, blankTime=0)

if probeEnergy is True:
    eProbe = net.board.probe(
        probeType=ProbeParameter.ENERGY,
        probeCondition=PerformanceProbeCondition(
            tStart=tStart,
            tEnd=net.net.numSteps,
            bufferSize=bufferSize,
            binSize=binSize,
        )
    )

    results = net.run(tStart + bufferSize * binSize - slack)
else:
    results = net.run()
# Out:
# Disabling output probing (probeOutput) in single streaming mode (streamOnce = True)
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |    7|
#
# # cores per network : 6.0
# # cores per repeater: 1.0
# Creating 19 additional copies per chip.
# Copy 1
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   13|
#
# Copy 2
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   19|
#
# Copy 3
# Repeater added at core 19
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   26|
#
# Copy 4
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   32|
#
# Copy 5
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   38|
#
# Copy 6
# Repeater added at core 38
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   45|
#
# Copy 7
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   51|
#
# Copy 8
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   57|
#
# Copy 9
# Repeater added at core 57
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   64|
#
# Copy 10
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   70|
#
# Copy 11
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   76|
#
# Copy 12
# Repeater added at core 76
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   83|
#
# Copy 13
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   89|
#
# Copy 14
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |   95|
#
# Copy 15
# Repeater added at core 95
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |  102|
#
# Copy 16
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |  108|
#
# Copy 17
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |  114|
#
# Copy 18
# Repeater added at core 114
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |  121|
#
# Copy 19
# Creating Network
# |   Type   |  W  |  H  |  C  | ker | str | pad |delay|neurons/Core|cores|
# |input     |   64|    1|    1|     |     |     |False|        1024|    1|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  256|     |     |     |True |         128|    2|
# |dense     |    1|    1|  242|     |     |     |False|         336|    1|
# |average   |    1|    1|   11|     |     |     |False|           0|    0|
# |Total                                                            |  127|
#
# Starting compilation of single chip copies
# Completed compilation of single chip copies in 249.52 seconds
# INFO:DRV:  SLURM is being run in background
# INFO:DRV:  Connecting to 134.134.68.69:45153
# INFO:DRV:      Host server up..............Done 0.50s
# INFO:DRV:      Encoding axons/synapses.....Done 4.46s
# INFO:DRV:      Compiling Embedded snips....Done 0.31s
# INFO:DRV:      Compiling MPDS Registers....Done 2.67ms
# INFO:HST:  Args chip=0 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299422.2095776/launcher_chip0_lmt0.bin --chips=1 --remote-relay=0 --epoch=0
# INFO:HST:  Lakemont_driver...
# INFO:DRV:      Booting up..................Done 0.83s
# INFO:DRV:      Encoding probes.............Done 0.57ms
# INFO:DRV:      Transferring probes.........Done 3.43ms
# INFO:DRV:      Configuring registers.......Done 3.56s
# INFO:DRV:      Executing...................Done 2.22ms
# INFO:DRV:      Processing timeseries.......Done 1.17ms
# INFO:HST:  Dump file exists....Removing it
# Saved single chip copy to ntidigitsBenchmark.board
# INFO:HST:  chip=0 cpu=0 halted, status=0x0
# Using per sample spike time: 3000steps (+ 0steps gap)
# /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/src/benchmarkSnips
# INFO:DRV:  SLURM is being run in background
# INFO:DRV:  Connecting to 134.134.68.69:41315
# INFO:DRV:      Host server up..............Done 0.31s
# INFO:DRV:      Encoding axons/synapses.....Done 0.20s
# INFO:DRV:      Compiling Embedded snips....Done 36.54s
# INFO:DRV:      Compiling Host snips........Done 1.12s
# INFO:DRV:      Compiling MPDS Registers....Done 3.84ms
# INFO:HST:  Args chip=0 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip0_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=0 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip0_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=0 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip0_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=1 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip1_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=1 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip1_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=1 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip1_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=2 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip2_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=2 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip2_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=2 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip2_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=3 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip3_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=3 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip3_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=3 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip3_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=4 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip4_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=4 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip4_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=4 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip4_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=5 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip5_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=5 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip5_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=5 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip5_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=6 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip6_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=6 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip6_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=6 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip6_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=7 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip7_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=7 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip7_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=7 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip7_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=8 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip8_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=8 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip8_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=8 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip8_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=9 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip9_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=9 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip9_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=9 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip9_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=10 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip10_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=10 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip10_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=10 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip10_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=11 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip11_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=11 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip11_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=11 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip11_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=12 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip12_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=12 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip12_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=12 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip12_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=13 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip13_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=13 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip13_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=13 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip13_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=14 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip14_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=14 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip14_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=14 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip14_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=15 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip15_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=15 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip15_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=15 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip15_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=16 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip16_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=16 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip16_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=16 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip16_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=17 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip17_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=17 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip17_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=17 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip17_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=18 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip18_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=18 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip18_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=18 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip18_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=19 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip19_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=19 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip19_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=19 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip19_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=20 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip20_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=20 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip20_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=20 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip20_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=21 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip21_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=21 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip21_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=21 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip21_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=22 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip22_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=22 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip22_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=22 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip22_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=23 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip23_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=23 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip23_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=23 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip23_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=24 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip24_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=24 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip24_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=24 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip24_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=25 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip25_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=25 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip25_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=25 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip25_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=26 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip26_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=26 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip26_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=26 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip26_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=27 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip27_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=27 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip27_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=27 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip27_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=28 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip28_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=28 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip28_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=28 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip28_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=29 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip29_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=29 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip29_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=29 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip29_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=30 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip30_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=30 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip30_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=30 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip30_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=31 cpu=0 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip31_lmt0.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=31 cpu=1 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip31_lmt1.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Args chip=31 cpu=2 /home/sshresth/nxsdk-nxsdk/nxsdk/driver/compilers/../../../temp/1612299472.7350237/launcher_chip31_lmt2.bin --chips=32 --remote-relay=0 --cpu-active-ratio=1
# INFO:HST:  Lakemont_driver...
# INFO:DRV:      Booting up..................Done 11.18s
# INFO:DRV:      Encoding probes.............Done 0.56ms
# INFO:DRV:      Transferring probes.........Done 0.01s
# INFO:DRV:      Configuring registers.......Done 0.16s
# INFO:DRV:      Transferring spikes.........Done 3.26ms
# Timer starts here
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 0
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 1
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 2
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 3
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 4
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 5
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 6
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 7
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 8
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 9
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 10
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 11
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 12
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 13
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 14
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 15
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 16
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 17
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 18
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 19
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 20
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 21
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 22
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 23
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 24
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 25
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 26
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 27
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 28
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 29
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 30
# INFO:HST:  Reading filename: /home/sshresth/nxsdk-nxsdk/nxsdk_modules/slayer/tutorials/ntidigits/ntidigitsBenchmark.board Programming Chip: 31
# INFO:HST:  Time Taken: 97.185 seconds.
# INFO:DRV:      Executing...................Done 101.12s
# INFO:DRV:      Processing timeseries.......Done 0.48s
# INFO:HST:  chip=0 cpu=0 halted, status=0x0
# INFO:HST:  chip=1 cpu=0 halted, status=0x0
# INFO:HST:  chip=8 cpu=0 halted, status=0x0
# INFO:HST:  chip=9 cpu=0 halted, status=0x0
# INFO:HST:  chip=10 cpu=0 halted, status=0x0
# INFO:HST:  chip=11 cpu=0 halted, status=0x0
# INFO:HST:  chip=12 cpu=0 halted, status=0x0
# INFO:HST:  chip=13 cpu=0 halted, status=0x0
# INFO:HST:  chip=14 cpu=0 halted, status=0x0
# INFO:HST:  chip=15 cpu=0 halted, status=0x0
# INFO:HST:  chip=16 cpu=0 halted, status=0x0
# INFO:HST:  chip=17 cpu=0 halted, status=0x0
# INFO:HST:  chip=18 cpu=0 halted, status=0x0
# INFO:HST:  chip=19 cpu=0 halted, status=0x0
# INFO:HST:  chip=20 cpu=0 halted, status=0x0
# INFO:HST:  chip=21 cpu=0 halted, status=0x0
# INFO:HST:  chip=22 cpu=0 halted, status=0x0
# INFO:HST:  chip=23 cpu=0 halted, status=0x0
# INFO:HST:  chip=24 cpu=0 halted, status=0x0
# INFO:HST:  chip=25 cpu=0 halted, status=0x0
# INFO:HST:  chip=26 cpu=0 halted, status=0x0
# INFO:HST:  chip=27 cpu=0 halted, status=0x0
# INFO:HST:  chip=28 cpu=0 halted, status=0x0
# INFO:HST:  chip=29 cpu=0 halted, status=0x0
# INFO:HST:  chip=30 cpu=0 halted, status=0x0
# INFO:HST:  chip=31 cpu=0 halted, status=0x0
# INFO:HST:  chip=0 cpu=1 halted, status=0x0
# INFO:HST:  chip=0 cpu=2 halted, status=0x0
# INFO:HST:  chip=1 cpu=1 halted, status=0x0
# INFO:HST:  chip=1 cpu=2 halted, status=0x0
# INFO:HST:  chip=2 cpu=0 halted, status=0x0
# INFO:HST:  chip=3 cpu=0 halted, status=0x0
# INFO:HST:  chip=4 cpu=0 halted, status=0x0
# INFO:HST:  chip=5 cpu=0 halted, status=0x0
# INFO:HST:  chip=6 cpu=0 halted, status=0x0
# INFO:HST:  chip=7 cpu=0 halted, status=0x0
# INFO:HST:  chip=8 cpu=1 halted, status=0x0
# INFO:HST:  chip=8 cpu=2 halted, status=0x0
# INFO:HST:  chip=9 cpu=1 halted, status=0x0
# INFO:HST:  chip=9 cpu=2 halted, status=0x0
# INFO:HST:  chip=10 cpu=1 halted, status=0x0
# INFO:HST:  chip=10 cpu=2 halted, status=0x0
# INFO:HST:  chip=11 cpu=1 halted, status=0x0
# INFO:HST:  chip=11 cpu=2 halted, status=0x0
# INFO:HST:  chip=12 cpu=1 halted, status=0x0
# INFO:HST:  chip=12 cpu=2 halted, status=0x0
# INFO:HST:  chip=13 cpu=1 halted, status=0x0
# INFO:HST:  chip=13 cpu=2 halted, status=0x0
# INFO:HST:  chip=14 cpu=1 halted, status=0x0
# INFO:HST:  chip=14 cpu=2 halted, status=0x0
# INFO:HST:  chip=15 cpu=1 halted, status=0x0
# INFO:HST:  chip=15 cpu=2 halted, status=0x0
# INFO:HST:  chip=16 cpu=1 halted, status=0x0
# INFO:HST:  chip=16 cpu=2 halted, status=0x0
# INFO:HST:  chip=17 cpu=1 halted, status=0x0
# INFO:HST:  chip=17 cpu=2 halted, status=0x0
# INFO:HST:  chip=18 cpu=1 halted, status=0x0
# INFO:HST:  chip=18 cpu=2 halted, status=0x0
# INFO:HST:  chip=19 cpu=1 halted, status=0x0
# INFO:HST:  chip=19 cpu=2 halted, status=0x0
# INFO:HST:  chip=20 cpu=1 halted, status=0x0
# INFO:HST:  chip=20 cpu=2 halted, status=0x0
# INFO:HST:  chip=21 cpu=1 halted, status=0x0
# INFO:HST:  chip=21 cpu=2 halted, status=0x0
# INFO:HST:  chip=22 cpu=1 halted, status=0x0
# INFO:HST:  chip=22 cpu=2 halted, status=0x0
# INFO:HST:  chip=23 cpu=1 halted, status=0x0
# INFO:HST:  chip=23 cpu=2 halted, status=0x0
# INFO:HST:  chip=24 cpu=1 halted, status=0x0
# INFO:HST:  chip=24 cpu=2 halted, status=0x0
# INFO:HST:  chip=25 cpu=1 halted, status=0x0
# INFO:HST:  chip=25 cpu=2 halted, status=0x0
# INFO:HST:  chip=26 cpu=1 halted, status=0x0
# INFO:HST:  chip=26 cpu=2 halted, status=0x0
# INFO:HST:  chip=27 cpu=1 halted, status=0x0
# INFO:HST:  chip=27 cpu=2 halted, status=0x0
# INFO:HST:  chip=28 cpu=1 halted, status=0x0
# INFO:HST:  chip=28 cpu=2 halted, status=0x0
# INFO:HST:  chip=29 cpu=1 halted, status=0x0
# INFO:HST:  chip=29 cpu=2 halted, status=0x0
# INFO:HST:  chip=30 cpu=1 halted, status=0x0
# INFO:HST:  chip=30 cpu=2 halted, status=0x0
# INFO:HST:  chip=31 cpu=1 halted, status=0x0
# INFO:HST:  chip=31 cpu=2 halted, status=0x0
# INFO:HST:  chip=2 cpu=1 halted, status=0x0
# INFO:HST:  chip=2 cpu=2 halted, status=0x0
# INFO:HST:  chip=3 cpu=1 halted, status=0x0
# INFO:HST:  chip=3 cpu=2 halted, status=0x0
# INFO:HST:  chip=4 cpu=1 halted, status=0x0
# INFO:HST:  chip=4 cpu=2 halted, status=0x0
# INFO:HST:  chip=5 cpu=1 halted, status=0x0
# INFO:HST:  chip=5 cpu=2 halted, status=0x0
# INFO:HST:  chip=6 cpu=1 halted, status=0x0
# INFO:HST:  chip=6 cpu=2 halted, status=0x0
# INFO:HST:  chip=7 cpu=1 halted, status=0x0
# INFO:HST:  chip=7 cpu=2 halted, status=0x0
# Completed 131072 timesteps in 109.06 seconds

# %%
net.net.numSamples
# Out:
# 2486

# %% [markdown]
# # Check accuracy

# %%
if streamOnce is False:
    results = results.reshape(results.shape[0], 11, -1).sum(axis=2)
    labels = dataset.labels
    accuracy = nxSlayer.s2l.checkAccuracy(labels, results)
    print('Final accuracy is {:.2f}%'.format(accuracy*100))

# %% [markdown]
# # Extract power measurements and plot them

# %%
if probeEnergy is True:
    dynamicPower = net.board.energyTimeMonitor.powerProfileStats.power['dynamic']  / numChips / net.numCopiesPerChip
    timePerTick  = net.board.energyTimeMonitor.powerProfileStats.timePerTimestep
    dynamicEnergyPerSample = dynamicPower * timePerTick * dataset.sampleLength / 1000

    print('Dynamic power :', dynamicPower, 'mW')
    print('Time per tick :', timePerTick, 'us')
    print('Ticks / sample:', dataset.sampleLength)
    print('Dynamic energy Per Sample :', dynamicEnergyPerSample, 'uJ')
# Out:
# Dynamic power : 10.892893181009958 mW
# Time per tick : 17.6250417494265 us
# Ticks / sample: 3000
# Dynamic energy Per Sample : 575.9630912620312 uJ

# %%
if probeEnergy is True:
    import matplotlib.pyplot as plt
    plt.figure(figsize=(20, 5))
    eProbe.plotPower()
    # plt.axis((0, 1, None, None))
